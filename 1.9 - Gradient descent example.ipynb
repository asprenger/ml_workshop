# %% [markdown]
# This is an example for solving a regression problem using the gradient descent algorithm.
#
# Consider the function $f(x)$ where $x=[x_0, x_1]$:
#
# $$
# f(x) = w_0 x_0^2 + w_1 x_1^2 + b
# $$
#
# The function value is a scalar $y = f(x)$.
#
# Assume we have a large set of examples $(x,y)$ that has been generated from $f(x)$.
#
# The goal is to estimate the parameters $w=[w_0, w_1]$ and $b$.
#
#
#
# The partial derivatives of $f(x)$ w.r.t. the parameters $w$ and $b$ are:
#
# $ \frac{\partial}{\partial w_0} f(x) = x_o^2$
#
# $ \frac{\partial}{\partial w_1} f(x) = x_1^2$
#
# $ \frac{\partial}{\partial b} f(x) = 1$
#
# Because this is a regression problem we use MSE as loss function:
#
# $L(x, y) = (f(x) - y)^2$
#
# The partial derivatives of $L$ w.r.t. the parameters $w$ and $b$ are calculated by applying the chain rule:
#
# $\frac{\partial}{\partial w_0} L = 2(f(x) - y) \ \frac{\partial}{\partial w_0} (f(x)-y) = 2(f(x) - y) \ x_0^2$
#
# $\frac{\partial}{\partial w_1} L = 2(f(x) - y) \ \frac{\partial}{\partial w_1} (f(x) - y) = 2(f(x) - y) \ x_1^2$
#
# $\frac{\partial}{\partial b} L = 2(f(x) - y) \ \frac{\partial}{\partial b} (f(x)-y) = 2(f(x) - y)$

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# f is parametrized with `w` and `b` so we can use it
# to calculate `y` and `y_hat`
def f(x, w, b):
    assert x.shape[0] == 2
    assert w.shape[0] == 2
    assert b.shape[0] == 1
    return w[0] * x[0]**2 + w[1] * x[1]**2 + b[0]

# the true parameters that we are trying to estimate
true_w = np.array([-0.8, 1.3])
true_b = np.array([0.5])

# initialize model parameters with small random values
w = np.random.normal(loc=0.0, scale=0.01, size=(2,))
b = np.random.normal(loc=0.0, scale=0.01, size=(1,))

# hyperparameter
alpha = 0.001
nb_iterations = 5000

# loss history
losses = []

for i in range(nb_iterations):
    
    # normally we would read x and y from a train dataset
    # but we simply calculate them on the fly
    x = (np.random.rand(2) * 4.0) - np.array([2.0, 2.0])
    y = f(x, true_w, true_b)

    # forward pass
    y_hat = f(x, w, b)
    
    # calculate loss for reporting, it is not required for 
    # the optimization algorithm
    loss = (y_hat - y)**2
    losses.append(loss)

    # backward pass
    
    # calculate partial derivatives of the loss w.r.t. w and b
    dloss_dw0 = 2 * (y_hat - y) * x[0]**2
    dloss_dw1 = 2 * (y_hat - y) * x[1]**2
    dloss_db = 2 * (y_hat - y)
    
    # apply the update rules
    w = w - alpha * np.array([dloss_dw0, dloss_dw1])
    b = b - alpha * np.array([dloss_db])

print('true parameters:', true_w, true_b)
print('estimated parameters', w, b)

# plot the loss over time
plt.figure(figsize=(10,10))
plt.title('Convergence plot')
plt.xlabel('step')
plt.ylabel('loss')
plt.plot(losses[:1000])
plt.show()
# Out:
# true parameters: [-0.8  1.3] [0.5]
# estimated parameters [-0.7927932   1.30721333] [0.47544958]

# %% [markdown]
# Always keep the goal in mind: we want to come up with parameters $w$ and $b$ that minimize the prediction error with regard to observations $x$ and $y$.
